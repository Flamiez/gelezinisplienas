# %%
import os
import random
from PIL import Image, ImageDraw
import torch
from diffusers import StableDiffusionInpaintPipeline
import transformers
import matplotlib.pyplot as plt

# %% [markdown]
# CONFIG

# %%
MODEL_ID = "sd-legacy/stable-diffusion-inpainting"
INPAINT_STRENGTH = 0.65
BACKGROUND_STRENGH = 0.45
GUIDANCE_SCALE = 4
NUM_INFERENCE_STEPS = 40
OBJECT_NUMBER = 5

IMAGE_COUNT = 300

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = StableDiffusionInpaintPipeline.from_pretrained(
    MODEL_ID,
    torch_dtype=torch.float16
)
pipe = pipe.to(device)
pipe.enable_attention_slicing()
# Out:
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.60it/s]An error occurred while trying to fetch C:\Users\jokub\.cache\huggingface\hub\models--sd-legacy--stable-diffusion-inpainting\snapshots\8a4288a76071f7280aedbdb3253bdb9e9d5d84bb\vae: Error no file named diffusion_pytorch_model.safetensors found in directory C:\Users\jokub\.cache\huggingface\hub\models--sd-legacy--stable-diffusion-inpainting\snapshots\8a4288a76071f7280aedbdb3253bdb9e9d5d84bb\vae.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# Loading pipeline components...:  29%|██▊       | 2/7 [00:00<00:01,  3.00it/s]An error occurred while trying to fetch C:\Users\jokub\.cache\huggingface\hub\models--sd-legacy--stable-diffusion-inpainting\snapshots\8a4288a76071f7280aedbdb3253bdb9e9d5d84bb\unet: Error no file named diffusion_pytorch_model.safetensors found in directory C:\Users\jokub\.cache\huggingface\hub\models--sd-legacy--stable-diffusion-inpainting\snapshots\8a4288a76071f7280aedbdb3253bdb9e9d5d84bb\unet.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# Loading pipeline components...: 100%|██████████| 7/7 [00:01<00:00,  3.64it/s]

# %%
def check_overlap(new_rect, occupied_rects):
    """Check if new_rect overlaps any existing rectangles"""
    x1, y1, x2, y2 = new_rect
    for ox1, oy1, ox2, oy2 in occupied_rects:
        # Check for rectangle overlap
        if not (x2 <= ox1 or x1 >= ox2 or y2 <= oy1 or y1 >= oy2):
            return True
    return False

# %%
# Paths
backgrounds_folder = "../GenerationData/Backgrounds"
objects_folder = "../GenerationData/Objects"
prompts_file = "../GenerationData/prompts.txt"

# Results paths
generatedImagesFolder = "../Datasets/GeneratedImages"
generatedMasksFolder = "../Datasets/GeneratedMasks"

# Load file paths
backgrounds = [os.path.join(backgrounds_folder, f) for f in os.listdir(backgrounds_folder)
               if f.lower().endswith((".png", ".jpg", ".jpeg"))]
objects = [os.path.join(objects_folder, f) for f in os.listdir(objects_folder)
           if f.lower().endswith((".png", ".jpg", ".jpeg"))]

prompts = []
# Each line new prompt
with open(prompts_file, "r") as f:
    prompts = f.read().splitlines()

# %%
inpainted = None
for i in range(IMAGE_COUNT):
    # Choose random prompt
    prompt = random.choice(prompts)

    # Pick one random background
    bg_path = random.choice(backgrounds)
    original_background = Image.open(bg_path).convert("RGB")

    # Randomly rotate the background (90, 180, or 270 degrees)
    rotation_angle = random.choice([0, 90, 180, 270])
    original_background = original_background.rotate(rotation_angle, expand=False)
    
    # Create a fully white mask (whole image = inpaint)
    white_mask = Image.new("L", original_background.size, 255)

    background_result = pipe(
        prompt=prompt,
        image=original_background,
        mask_image=white_mask,
        guidance_scale=GUIDANCE_SCALE,
        strength=BACKGROUND_STRENGH,
        num_inference_steps=NUM_INFERENCE_STEPS,
    )

    background = background_result.images[0].convert("RGBA")

    # Create a blank black mask
    mask = Image.new("L", background.size, 0)
    # If we don't want rotating masks
    # draw = ImageDraw.Draw(mask)

    # Random number of objects
    num_objects = random.randint(1, OBJECT_NUMBER)
    chosen_objects = random.sample(objects, num_objects)

    occupied = []
    for obj_path in chosen_objects:
        obj = Image.open(obj_path).convert("RGBA")
        # obj = obj.rotate(random.uniform(0, 360), expand=True)
        obj_width, obj_height = obj.width, obj.height

        # Try to place object without overlapping (limit attempts)
        max_attempts = 100
        for attempt in range(max_attempts):
            max_x = background.width - obj_width
            max_y = background.height - obj_height
            pos = (random.randint(0, max_x), random.randint(0, max_y))
            new_rect = (pos[0], pos[1], pos[0] + obj_width, pos[1] + obj_height)

            if not check_overlap(new_rect, occupied):
                # Place object
                background.alpha_composite(obj, pos)
                # Update mask
                obj_mask = obj.split()[-1]  # alpha channel
                mask.paste(obj_mask, pos, obj_mask)
                # If we don't want rotating masks
                # draw.rectangle(new_rect, fill=255)
                # Add to occupied
                occupied.append(new_rect)
                break
        else:
            print(f"Could not place {obj_path} without overlap after {max_attempts} attempts.")

    # Reverse Mask for backgrounds (comment out for objects or if data is reversed)
    reverse_mask = Image.eval(mask, lambda p: 255 - p)
    composite_rgb = background.convert("RGB")

    # Generation
    result = pipe(
        prompt=prompt,
        image=composite_rgb,
        mask_image=reverse_mask,
        guidance_scale=GUIDANCE_SCALE,
        strength=INPAINT_STRENGTH,
        num_inference_steps=NUM_INFERENCE_STEPS,
    )

    inpainted = result.images[0]

    # Create folders if don't exist
    os.makedirs(generatedImagesFolder, exist_ok=True)
    os.makedirs(generatedMasksFolder, exist_ok=True)
    # Save
    inpainted.save(os.path.join(generatedImagesFolder, f"{i}.png"))
    mask.save(os.path.join(generatedMasksFolder, f"{i}.png"))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (109 > 77). Running this sequence through the model will result in indexing errors
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.45it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.35it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.06it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.02it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.31it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.76it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.72it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.07it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.85it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.23it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.06it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.12it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.90it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.10it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.12it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.50it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.43it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.59it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.39it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.48it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.45it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.66it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.05it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.94it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.88it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.21it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.02it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.47it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.37it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.53it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.34it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.49it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.92it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 11.96it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.08it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.45it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.33it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.52it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.32it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.35it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.07it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.43it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.95it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.33it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.21it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.51it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.39it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.40it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.19it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 11.30it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.74it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.24it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.59it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.78it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.22it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.51it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.25it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.29it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.25it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.37it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.40it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.50it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.89it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.76it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.68it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.46it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.27it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.45it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.95it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.34it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.21it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.83it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.31it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 11.76it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.71it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.16it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.35it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.24it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.81it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.46it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.36it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.33it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.02it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.93it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.80it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.27it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.55it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.06it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.83it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.95it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.07it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.01it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.90it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.36it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.32it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.85it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.97it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.11it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.84it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.01it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.87it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.07it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.98it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 11.95it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.58it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.99it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.81it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.95it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.79it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.83it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.86it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.06it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.03it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.57it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.38it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.59it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.96it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.07it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.72it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.10it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.22it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.68it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.01it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.49it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.19it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.38it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.63it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.79it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.43it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.78it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.73it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.84it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.72it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.20it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.67it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.28it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.61it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.18it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.25it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.58it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.57it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.69it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.44it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.32it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.44it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.75it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.69it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.63it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.50it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.71it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.57it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.75it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.14it/s]
# ...
# 100%|██████████| 18/18 [00:01<00:00, 12.92it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 11.48it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.99it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.33it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.56it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.39it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.79it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.67it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.86it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.79it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.09it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.59it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.95it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.06it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.93it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.68it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.88it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.34it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.13it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.62it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.80it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.32it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.46it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 11.81it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.28it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 11.96it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.41it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.64it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 11.99it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.34it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.47it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.54it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.50it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.32it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.02it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.82it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.89it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.65it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.52it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.68it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 13.11it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:01<00:00, 13.08it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.26it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.17it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.10it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.69it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.22it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.85it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.60it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.48it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 18/18 [00:01<00:00, 12.73it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['land . soft , natural lighting from above , no harsh shadows , resembling a drone - captured midday photograph . top - down view , realistic , high detail .']
# 100%|██████████| 26/26 [00:02<00:00, 12.97it/s]

# %% [markdown]
# RUN THIS BELOW JUST TO CHECK OR TEST

# %%
fig, axs = plt.subplots(1, 4, figsize=(16, 5))
axs[0].imshow(composite_rgb)
axs[0].set_title(f"Composite")
axs[0].axis("off")

axs[1].imshow(mask, cmap="gray")
axs[1].set_title("Mask (white = inpaint)")
axs[1].axis("off")

axs[2].imshow(reverse_mask, cmap="gray")
axs[2].set_title("Reverse Mask (white = keep)")
axs[2].axis("off")

axs[3].imshow(inpainted)
axs[3].set_title("Inpainted Result")
axs[3].axis("off")

plt.tight_layout()
plt.show()
